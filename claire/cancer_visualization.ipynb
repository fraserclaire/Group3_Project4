# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

energy_cancer = pd.read_csv("energy_cancer_statePerYear.csv")
energy_cancer.head()

cancer_rate_columns = [col for col in energy_cancer.columns if '_AllSites' in col]

# Select only the columns related to cancer rates and the 'State Abbreviation'
all_sites = energy_cancer[['State Abbreviation'] + cancer_rate_columns]

# Set the 'State Abbreviation' as the index
all_sites.set_index('State Abbreviation', inplace=True)

# Exclude 'US' row
all_sites = all_sites[all_sites.index != 'US']
all_sites = all_sites[all_sites.index != 'DC']

# Read in state population counts
pop = pd.read_csv("state_populations.csv")
pop.rename(columns={'State': 'State Abbreviation'}, inplace=True)

# Merge the 'pop' DataFrame with the 'energy_cancer' DataFrame on the 'State Abbreviation' column
merged_df = pd.merge(all_sites, pop, on='State Abbreviation')

# print(merged_df.head())

# Create new calculated columns by dividing each *_AllSites column by the Total_Population column
for column in cancer_rate_columns:
    merged_df[column + '_per_capita'] = merged_df[column] / merged_df['Total_Population']

merged_df.set_index('State Abbreviation', inplace=True)

merged_df = merged_df.iloc[:, -11:]

# Convert cancer rates from per capita to percentages
merged_df_percentage = merged_df * 100

# List of years
years = [str(year) for year in range(2010, 2021)]

# Set seaborn style
sns.set_style("whitegrid")

# Plotting a box plot for all states with cool effects
plt.figure(figsize=(10, 6))
sns.boxplot(data=merged_df_percentage, palette="YlOrRd", linewidth=2, showfliers=True)
plt.title('Rates of All Cancer Sites - United States', fontsize=16, fontweight='bold')
plt.ylabel('Cancer Rate (%)', fontsize=14, fontweight='bold')
plt.xticks(range(11), years, fontsize=14)
plt.yticks(fontsize=14)
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
plt.tight_layout()

# Save the plot as PNG
plt.savefig('allcancer_rates.png')

plt.show()

# %%
cancer_rate_columns = [col for col in energy_cancer.columns if '_AllSites' in col]

# Select only the columns related to cancer rates and the 'State Abbreviation'
all_sites = energy_cancer[['State Abbreviation'] + cancer_rate_columns]

# Set the 'State Abbreviation' as the index
all_sites.set_index('State Abbreviation', inplace=True)

# Exclude 'US' row
all_sites = all_sites[all_sites.index != 'US']
all_sites = all_sites[all_sites.index != 'DC']

# Merge the 'pop' DataFrame with the 'energy_cancer' DataFrame on the 'State Abbreviation' column
merged_df = pd.merge(all_sites, pop, on='State Abbreviation')

# print(merged_df.head())

# Create new calculated columns by dividing each *_AllSites column by the Total_Population column
for column in cancer_rate_columns:
    merged_df[column + '_per_capita'] = merged_df[column] / merged_df['Total_Population']

merged_df.set_index('State Abbreviation', inplace=True)

merged_df = merged_df.iloc[:, -11:]

# Sort the DataFrame by the '2020_AllSites_per_capita' values
merged_df_sorted = merged_df.sort_values(by='2020_AllSites_per_capita', ascending=False)

# Select the top 10 states with the highest '2020_AllSites_per_capita' values
top_10_states = merged_df_sorted.head(10)


# print(top_10_states)


plt.figure(figsize=(10, 6))
for state in top_10_states.index:
    plt.plot(top_10_states.columns, top_10_states.loc[state], label=state, marker='o', linestyle='-')

plt.title('Top 10 US States: All Sites Cancer Rates')
plt.ylabel('Cancer Rate', fontsize=14, fontweight='bold')
plt.xticks(range(11), years, fontsize=14)
plt.yticks(fontsize=12)
plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
cancer_rate_columns = [col for col in energy_cancer.columns if '_AllSites' in col]

# Select only the columns related to cancer rates and the 'State Abbreviation'
all_sites = energy_cancer[['State Abbreviation'] + cancer_rate_columns]

# Set the 'State Abbreviation' as the index
all_sites.set_index('State Abbreviation', inplace=True)

# Exclude 'US' row
all_sites = all_sites[all_sites.index != 'US']
all_sites = all_sites[all_sites.index != 'DC']

# Merge the 'pop' DataFrame with the 'energy_cancer' DataFrame on the 'State Abbreviation' column
merged_df = pd.merge(all_sites, pop, on='State Abbreviation')

# print(merged_df.head())

# Create new calculated columns by dividing each *_AllSites column by the Total_Population column
for column in cancer_rate_columns:
    merged_df[column + '_per_capita'] = merged_df[column] / merged_df['Total_Population']

merged_df.set_index('State Abbreviation', inplace=True)

merged_df = merged_df.iloc[:, -11:]

# Sort the DataFrame by the '2020_AllSites_per_capita' values
merged_df_sorted = merged_df.sort_values(by='2020_AllSites_per_capita', ascending=False)

# Select the top 10 states with the highest '2020_AllSites_per_capita' values
top_10_states = merged_df_sorted.head(10)


# print(top_10_states)


plt.figure(figsize=(10, 6))
for state in top_10_states.index:
    plt.plot(top_10_states.columns, top_10_states.loc[state], label=state, marker='o', linestyle='-')

plt.title('Top 10 US States: All Sites Cancer Rates')
plt.ylabel('Cancer Rate', fontsize=14, fontweight='bold')
plt.xticks(range(11), years, fontsize=14)
plt.yticks(fontsize=12)
plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
cancer_rate_columns = [col for col in energy_cancer.columns if '_AllSites' in col]

# Select only the columns related to cancer rates and the 'State Abbreviation'
all_sites = energy_cancer[['State Abbreviation'] + cancer_rate_columns]

# Set the 'State Abbreviation' as the index
all_sites.set_index('State Abbreviation', inplace=True)

# Exclude 'US' row
all_sites = all_sites[all_sites.index != 'US']
all_sites = all_sites[all_sites.index != 'DC']

# Merge the 'pop' DataFrame with the 'energy_cancer' DataFrame on the 'State Abbreviation' column
merged_df = pd.merge(all_sites, pop, on='State Abbreviation')

# print(merged_df.head())

# Create new calculated columns by dividing each *_AllSites column by the Total_Population column
for column in cancer_rate_columns:
    merged_df[column + '_per_capita'] = merged_df[column] / merged_df['Total_Population']

merged_df.set_index('State Abbreviation', inplace=True)

merged_df = merged_df.iloc[:, -11:]

# Sort the DataFrame by the '2020_AllSites_per_capita' values
merged_df_sorted = merged_df.sort_values(by='2020_AllSites_per_capita', ascending=False)

# Select the top 10 states with the highest '2020_AllSites_per_capita' values
last_10_states = merged_df_sorted.tail(10)


# print(last_10_states)


plt.figure(figsize=(10, 6))
for state in last_10_states.index:
    plt.plot(last_10_states.columns, last_10_states.loc[state], label=state, marker='o', linestyle='-')

plt.title('Bottom 10 States: All Sites Cancer Rates Over the Years')
plt.ylabel('Cancer Rate', fontsize=14, fontweight='bold')
plt.xticks(range(11), years, fontsize=14)
plt.yticks(fontsize=12)
plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
# Create a custom grayscale palette for the bottom 10 states
bottom_palette = sns.color_palette("Greys", n_colors=10)

plt.figure(figsize=(10, 6))

# Plot the top states
for state in top_10_states.index:
    plt.plot(merged_df.columns, top_10_states.loc[state, merged_df.columns], label=state, marker='o', linestyle='-')

# Plot the bottom states
for i, state in enumerate(last_10_states.index):
    plt.plot(merged_df.columns, last_10_states.loc[state, merged_df.columns], label=state, color=bottom_palette[i], alpha=0.5)



years = [str(year) for year in range(2010, 2021)]

plt.title('Top and Bottom US States: All Sites Cancer Rates')
plt.xlabel('Year')
plt.ylabel('Cancer Rate', fontsize=14, fontweight='bold')
plt.xticks(range(1, len(years) + 1), years)
plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)

# Save the plot as PNG
plt.savefig('allcancer_rates_topBottomTen.png')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

energy_cancer = pd.read_csv("energy_cancer_statePerYear.csv")
energy_cancer.head()

lcancer_rate_columns = [col for col in energy_cancer.columns if '_LungBronchus' in col]

# Select only the columns related to cancer rates and the 'State Abbreviation'
all_sites = energy_cancer[['State Abbreviation'] + lcancer_rate_columns]

# Set the 'State Abbreviation' as the index
all_sites.set_index('State Abbreviation', inplace=True)

# Exclude 'US' row
all_sites = all_sites[all_sites.index != 'US']
all_sites = all_sites[all_sites.index != 'DC']

# Merge the 'pop' DataFrame with the 'energy_cancer' DataFrame on the 'State Abbreviation' column
merged_df = pd.merge(all_sites, pop, on='State Abbreviation')

# print(merged_df.head())

# Create new calculated columns by dividing each *_AllSites column by the Total_Population column
for column in lcancer_rate_columns:
    merged_df[column + '_per_capita'] = merged_df[column] / merged_df['Total_Population']

merged_df.set_index('State Abbreviation', inplace=True)

merged_df = merged_df.iloc[:, -11:]

# Convert cancer rates from per capita to percentages
merged_df_percentage = merged_df * 100

# List of years
years = [str(year) for year in range(2010, 2021)]

# Set seaborn style
sns.set_style("whitegrid")

# Plotting a box plot for all states with cool effects
plt.figure(figsize=(10, 6))
sns.boxplot(data=merged_df_percentage, palette="BuPu", linewidth=2, showfliers=True)
plt.title('Rates of Lung/Bronchus Cancer Sites - United States', fontsize=16, fontweight='bold')
plt.ylabel('Cancer Rate (%)', fontsize=14, fontweight='bold')
plt.xticks(range(11), years, fontsize=12)
plt.yticks(fontsize=14)
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
plt.tight_layout()

# Save the plot as PNG
plt.savefig('lungcancer_rates.png')

plt.show()

# %%
energy_cancer = pd.read_csv("energy_cancer_statePerYear.csv")
energy_cancer.head()

lcancer_rate_columns = [col for col in energy_cancer.columns if '_LungBronchus' in col]

# Select only the columns related to cancer rates and the 'State Abbreviation'
all_sites = energy_cancer[['State Abbreviation'] + lcancer_rate_columns]

# Set the 'State Abbreviation' as the index
all_sites.set_index('State Abbreviation', inplace=True)

# Exclude 'US' row
all_sites = all_sites[all_sites.index != 'US']
all_sites = all_sites[all_sites.index != 'DC']

# Merge the 'pop' DataFrame with the 'energy_cancer' DataFrame on the 'State Abbreviation' column
merged_df = pd.merge(all_sites, pop, on='State Abbreviation')

# print(merged_df.head())

# Create new calculated columns by dividing each *_AllSites column by the Total_Population column
for column in lcancer_rate_columns:
    merged_df[column + '_per_capita'] = merged_df[column] / merged_df['Total_Population']

merged_df.set_index('State Abbreviation', inplace=True)

merged_df = merged_df.iloc[:, -11:]

# merged_df.head()

# Sort the DataFrame by the '2020_AllSites_per_capita' values
merged_df_sorted = merged_df.sort_values(by='2020_LungBronchus_per_capita', ascending=False)
merged_df_sorted

# Select the top 10 states with the highest '2020_AllSites_per_capita' values
top_10_states = merged_df_sorted.head(10)

# print(top_10_states)

# Convert cancer rates from per capita to percentages
merged_df_percentage = merged_df * 100

# List of years
years = [str(year) for year in range(2010, 2021)]

plt.figure(figsize=(10, 6))
for state in top_10_states.index:
    plt.plot(top_10_states.columns, top_10_states.loc[state], label=state, marker='o', linestyle='-')

plt.title('Top 10 US States: Lung/Bronchal Cancer Rates')
plt.ylabel('Cancer Rate', fontsize=14, fontweight='bold')
plt.xticks(range(11), years, fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)

# Save the plot as PNG
plt.savefig('lungbronchal_rates.png')

plt.show()

# %%
energy_cancer = pd.read_csv("energy_cancer_statePerYear.csv")
energy_cancer.head()

lcancer_rate_columns = [col for col in energy_cancer.columns if '_LungBronchus' in col]

# Select only the columns related to cancer rates and the 'State Abbreviation'
all_sites = energy_cancer[['State Abbreviation'] + lcancer_rate_columns]

# Set the 'State Abbreviation' as the index
all_sites.set_index('State Abbreviation', inplace=True)

# Exclude 'US' row
all_sites = all_sites[all_sites.index != 'US']
all_sites = all_sites[all_sites.index != 'DC']

# Merge the 'pop' DataFrame with the 'energy_cancer' DataFrame on the 'State Abbreviation' column
merged_df = pd.merge(all_sites, pop, on='State Abbreviation')

# print(merged_df.head())

# Create new calculated columns by dividing each *_AllSites column by the Total_Population column
for column in lcancer_rate_columns:
    merged_df[column + '_per_capita'] = merged_df[column] / merged_df['Total_Population']

merged_df.set_index('State Abbreviation', inplace=True)

merged_df = merged_df.iloc[:, -11:]

# merged_df.head()

# Sort the DataFrame by the '2020_AllSites_per_capita' values
merged_df_sorted = merged_df.sort_values(by='2020_LungBronchus_per_capita', ascending=False)
merged_df_sorted

# Select the top 10 states with the highest '2020_AllSites_per_capita' values
last_10_states = merged_df_sorted.tail(10)

# print(last_10_states)

# Convert cancer rates from per capita to percentages
merged_df_percentage = merged_df * 100

# List of years
years = [str(year) for year in range(2010, 2021)]

plt.figure(figsize=(10, 6))
for state in last_10_states.index:
    plt.plot(last_10_states.columns, last_10_states.loc[state], label=state, marker='o', linestyle='-')

plt.title('Bottom 10 US States: Lung/Bronchal Cancer Rates')
plt.ylabel('Cancer Rate', fontsize=14, fontweight='bold')
plt.xticks(range(11), years, fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
# Create a custom grayscale palette for the bottom 10 states
bottom_palette = sns.color_palette("Greys", n_colors=10)

# Plotting the data
plt.figure(figsize=(10, 6))

# Plot the top states
for state in top_10_states.index:
    plt.plot(merged_df.columns, top_10_states.loc[state, merged_df.columns], label=state, marker='o', linestyle='-')

# Plot the bottom states with the custom grayscale palette
for i, state in enumerate(last_10_states.index):
    plt.plot(merged_df.columns, last_10_states.loc[state, merged_df.columns], label=state, color=bottom_palette[i], alpha=0.5)
plt.title('Top and Bottom US States: Lung/Bronchal Cancer Rates')
plt.ylabel('Cancer Rate')
plt.xticks(range(11), years, fontsize=12)
plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)

# Save the plot as PNG
plt.savefig('allcancer_rates_topBottomTen.png')

plt.show()
