# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

energy_cancer = pd.read_csv("energy_cancer_statePerYearwPop.csv")
energy_cancer.head()

# Select only the columns with _AllSites_perCapita
cancer_rate_columns = [col for col in energy_cancer.columns if '_AllSites_perCapita' in col]

# Select only the columns related to cancer rates and the 'State Abbreviation'
all_sites = energy_cancer[['State Abbreviation'] + cancer_rate_columns]

# Set the 'State Abbreviation' as the index
all_sites.set_index('State Abbreviation', inplace=True)

# Exclude 'US' row
all_sites = all_sites[all_sites.index != 'US']
all_sites = all_sites[all_sites.index != 'DC']

all_sites_percentage = all_sites * 100
all_sites_percentage

# List of years
years = [str(year) for year in range(2010, 2021)]

# Set seaborn style
sns.set_style("whitegrid")

# Plotting
plt.figure(figsize=(10, 6))
sns.boxplot(data=all_sites_percentage, palette="YlOrRd", linewidth=2, showfliers=True)
plt.title('Rates of All Cancer Sites - United States', fontsize=15, fontweight='bold')
plt.ylabel('Cancer Rate (%)', fontsize=14)
plt.xticks(range(11), years, fontsize=14)
plt.yticks(fontsize=14)
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
plt.tight_layout()

# Save the plot as PNG
plt.savefig('allcancer_rates.png')

plt.show()

# %%
# Select only the columns with _AllSites_perCapita
cancer_rate_columns = [col for col in energy_cancer.columns if '_AllSites_perCapita' in col]

# Select only the columns related to cancer rates and the 'State Abbreviation'
all_sites = energy_cancer[['State Abbreviation'] + cancer_rate_columns]

# Set the 'State Abbreviation' as the index
all_sites.set_index('State Abbreviation', inplace=True)

# Exclude 'US' row
all_sites = all_sites[all_sites.index != 'US']
all_sites = all_sites[all_sites.index != 'DC']

all_sites_percentage = all_sites * 100
all_sites_percentage

# List of years
years = [str(year) for year in range(2010, 2021)]


# Sort the DataFrame by the '2020_AllSites_per_capita' values
all_sites_percentage_sorted = all_sites_percentage.sort_values(by='2020_AllSites_perCapita', ascending=False)

# Select the top 10 states with the highest '2020_AllSites_per_capita' values
top_10_states = all_sites_percentage_sorted.head(10)


# print(top_10_states)


# plt.figure(figsize=(10, 6))
# for state in top_10_states.index:
#     plt.plot(top_10_states.columns, top_10_states.loc[state], label=state, marker='o', linestyle='-')

# plt.title('Top 10 US States: All Sites Cancer Rates')
# plt.ylabel('Cancer Rate', fontsize=14, fontweight='bold')
# plt.xticks(range(11), years, fontsize=14)
# plt.yticks(fontsize=12)
# plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.grid(True)
# plt.show()

# %%
# Select only the columns with _AllSites_perCapita
cancer_rate_columns = [col for col in energy_cancer.columns if '_AllSites_perCapita' in col]

# Select only the columns related to cancer rates and the 'State Abbreviation'
all_sites = energy_cancer[['State Abbreviation'] + cancer_rate_columns]

# Set the 'State Abbreviation' as the index
all_sites.set_index('State Abbreviation', inplace=True)

# Exclude 'US' row
all_sites = all_sites[all_sites.index != 'US']
all_sites = all_sites[all_sites.index != 'DC']

all_sites_percentage = all_sites * 100
all_sites_percentage

# List of years
years = [str(year) for year in range(2010, 2021)]


# Sort the DataFrame by the '2020_AllSites_per_capita' values
all_sites_percentage_sorted = all_sites_percentage.sort_values(by='2020_AllSites_perCapita', ascending=False)
# Select the top 10 states with the highest '2020_AllSites_per_capita' values
last_10_states = all_sites_percentage_sorted.tail(10)


# print(last_10_states)


# plt.figure(figsize=(10, 6))
# for state in last_10_states.index:
#     plt.plot(last_10_states.columns, last_10_states.loc[state], label=state, marker='o', linestyle='-')

# plt.title('Bottom 10 States: All Sites Cancer Rates Over the Years')
# plt.ylabel('Cancer Rate', fontsize=14, fontweight='bold')
# plt.xticks(range(11), years, fontsize=14)
# plt.yticks(fontsize=12)
# plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.grid(True)
# plt.show()

# %%
# Create a custom grayscale palette for the bottom 10 states
bottom_palette = sns.color_palette("Greys", n_colors=10)

plt.figure(figsize=(10, 6))

# Plot the top states
for state in top_10_states.index:
    plt.plot(top_10_states.columns, top_10_states.loc[state, top_10_states.columns], label=state, marker='o', linestyle='-')

# Plot the bottom states
for i, state in enumerate(last_10_states.index):
    plt.plot(last_10_states.columns, last_10_states.loc[state, top_10_states.columns], label=state, color=bottom_palette[i], alpha=0.5)



years = [str(year) for year in range(2010, 2021)]

plt.title('Top and Bottom US States: All Sites Cancer Rates', fontsize=15, fontweight='bold')
plt.ylabel('Cancer Rate (%)', fontsize=14)
plt.xticks(range(11), years, fontsize=12)
plt.yticks(fontsize=12)
legend = plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
legend.get_title().set_fontweight('bold')
plt.grid(True)

# Save the plot as PNG
plt.savefig('allcancer_rates_topBottomTen.png', bbox_inches='tight')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
energy_cancer = pd.read_csv("energy_cancer_statePerYearwPop.csv")
energy_cancer.head()

# Select only the columns with _AllSites_perCapita
lcancer_rate_columns = [col for col in energy_cancer.columns if '_LungBronchus_perCapita' in col]

# Select only the columns related to cancer rates and the 'State Abbreviation'
lung_sites = energy_cancer[['State Abbreviation'] + lcancer_rate_columns]

# Set the 'State Abbreviation' as the index
lung_sites.set_index('State Abbreviation', inplace=True)

# Exclude 'US' row
lung_sites = lung_sites[lung_sites.index != 'US']
lung_sites = lung_sites[lung_sites.index != 'DC']

lung_sites_percentage = lung_sites * 100
lung_sites_percentage

# List of years
years = [str(year) for year in range(2010, 2021)]

# Set seaborn style
sns.set_style("whitegrid")

# Plotting
plt.figure(figsize=(10, 6))
sns.boxplot(data=lung_sites_percentage, palette="BuPu", linewidth=2, showfliers=True)
plt.title('Rates of Lung/Bronchus Cancer Sites - United States', fontsize=15, fontweight='bold')
plt.ylabel('Cancer Rate (%)', fontsize=14)
plt.xticks(range(11), years, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
plt.tight_layout()

# Save the plot as PNG
plt.savefig('lungcancer_rates.png')

plt.show()

# %%
energy_cancer = pd.read_csv("energy_cancer_statePerYearwPop.csv")
energy_cancer.head()

# Select only the columns with _AllSites_perCapita
lcancer_rate_columns = [col for col in energy_cancer.columns if '_LungBronchus_perCapita' in col]

# Select only the columns related to cancer rates and the 'State Abbreviation'
lung_sites = energy_cancer[['State Abbreviation'] + lcancer_rate_columns]

# Set the 'State Abbreviation' as the index
lung_sites.set_index('State Abbreviation', inplace=True)

# Exclude 'US' row
lung_sites = lung_sites[lung_sites.index != 'US']
lung_sites = lung_sites[lung_sites.index != 'DC']

lung_sites_percentage = lung_sites * 100
lung_sites_percentage

# List of years
years = [str(year) for year in range(2010, 2021)]

# Sort the DataFrame by the '2020_AllSites_per_capita' values
lung_sites_percentage_sorted = lung_sites_percentage.sort_values(by='2020_LungBronchus_perCapita', ascending=False)
# Select the top 10 states with the highest '2020_AllSites_per_capita' values
top_10_states = lung_sites_percentage_sorted.head(10)

# print(top_10_states)

# plt.figure(figsize=(10, 6))
# for state in top_10_states.index:
#     plt.plot(top_10_states.columns, top_10_states.loc[state], label=state, marker='o', linestyle='-')

# plt.title('Top 10 US States: Lung/Bronchal Cancer Rates')
# plt.ylabel('Cancer Rate', fontsize=14, fontweight='bold')
# plt.xticks(range(11), years, fontsize=12)
# plt.yticks(fontsize=12)
# plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.grid(True)

# # Save the plot as PNG
# # plt.savefig('lungbronchal_rates.png')

# plt.show()

# %%
energy_cancer = pd.read_csv("energy_cancer_statePerYearwPop.csv")
energy_cancer.head()

# Select only the columns with _AllSites_perCapita
lcancer_rate_columns = [col for col in energy_cancer.columns if '_LungBronchus_perCapita' in col]

# Select only the columns related to cancer rates and the 'State Abbreviation'
lung_sites = energy_cancer[['State Abbreviation'] + lcancer_rate_columns]

# Set the 'State Abbreviation' as the index
lung_sites.set_index('State Abbreviation', inplace=True)

# Exclude 'US' row
lung_sites = lung_sites[lung_sites.index != 'US']
lung_sites = lung_sites[lung_sites.index != 'DC']

lung_sites_percentage = lung_sites * 100
lung_sites_percentage

# List of years
years = [str(year) for year in range(2010, 2021)]

# Sort the DataFrame by the '2020_AllSites_per_capita' values
lung_sites_percentage_sorted = lung_sites_percentage.sort_values(by='2020_LungBronchus_perCapita', ascending=False)
# Select the top 10 states with the highest '2020_AllSites_per_capita' values
last_10_states = lung_sites_percentage_sorted.tail(10)

# print(last_10_states)

# plt.figure(figsize=(10, 6))
# for state in last_10_states.index:
#     plt.plot(last_10_states.columns, last_10_states.loc[state], label=state, marker='o', linestyle='-')

# plt.title('Bottom 10 US States: Lung/Bronchal Cancer Rates')
# plt.ylabel('Cancer Rate (%)', fontsize=14, fontweight='bold')
# plt.xticks(range(11), years, fontsize=14)
# plt.yticks(fontsize=12)
# plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.grid(True)
# plt.show()

# %%
# Create a custom grayscale palette for the bottom 10 states
bottom_palette = sns.color_palette("Greys", n_colors=10)

# List of years
years = [str(year) for year in range(2010, 2021)]

# top_10_states
# Plotting the data
plt.figure(figsize=(10, 6))

# Plot the top states
for state in top_10_states.index:
    plt.plot(top_10_states.columns, top_10_states.loc[state, top_10_states.columns], label=state, marker='o', linestyle='-')

# Plot the bottom states
for i, state in enumerate(last_10_states.index):
    plt.plot(last_10_states.columns, last_10_states.loc[state, top_10_states.columns], label=state, color=bottom_palette[i], alpha=0.5)

plt.title('Top and Bottom US States: Lung/Bronchal Cancer Rates', fontsize=15, fontweight='bold')
plt.ylabel('Cancer Rate (%)', fontsize=14)
plt.xticks(range(11), years, fontsize=12)
plt.yticks(fontsize=12)
legend = plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
legend.get_title().set_fontweight('bold')
plt.grid(True)

# Save the plot as PNG
plt.savefig('lungBronchalCancer_rates_topBottomTen.png', bbox_inches='tight')
plt.show()
