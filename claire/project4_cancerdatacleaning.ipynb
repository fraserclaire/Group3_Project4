# %%
import pandas as pd
import csv

# %%
# Read the cancer dataset
cancer_data = pd.read_csv(".csv")
cancer_data

# %%
# Read in the state, region assignment data
state_region = pd.read_csv("state lat lon.csv")
state_region
# Out:
#                    State   Latitude   Longitude  reduced  reduced.1 concat  \
# 0                Alabama  32.806671  -86.791130       32        -86  32-86
# 1                 Alaska  61.370716 -152.404419       61        -15  61-15
# 2                Arizona  33.729759 -111.431221       33        -11  33-11
# 3               Arkansas  34.969704  -92.373123       34        -92  34-92
# 4             California  36.116203 -119.681564       36        -11  36-11
# 5               Colorado  39.059811 -105.311104       39        -10  39-10
# 6            Connecticut  41.597782  -72.755371       41        -72  41-72
# 7               Delaware  39.318523  -75.507141       39        -75  39-75
# 8   District of Columbia  38.897438  -77.026817       38        -77  38-77
# 9                Florida  27.766279  -81.686783       27        -81  27-81
# 10               Georgia  33.040619  -83.643074       33        -83  33-83
# ...

# %%
# Merge datasets
cancer_withRegion = pd.merge(cancer_data, state_region[['State', 'sub-region']], on='State', how='left')
cancer_withRegion

# %%
#
