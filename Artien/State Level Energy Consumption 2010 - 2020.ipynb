# %%
# Necessary Imports
import pandas as pd

# %%
# Read in the excel file
sheets = ['Coal','Natural Gas','Petroleum','Nuclear','Total Renewable Energy']


energy_consumption= pd.read_excel('use_energy_source.xlsx',sheet_name=sheets,index_col=None)

# %%
# Review one of the dataframes in the variable
energy_consumption['Coal']
# Out:
#    Coal total consumption, billion Btu  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                                  NaN         NaN         NaN         NaN
# 1                                State      1960.0      1961.0      1962.0
# 2                                   AK      7189.0     11552.0     13559.0
# 3                                   AL    395400.0    382455.0    427177.0
# 4                                   AR       356.0       275.0       160.0
# 5                                   AZ       210.0       211.0      6291.0
# 6                                   CA     35903.0     59106.0     39681.0
# 7                                   CO     68206.0     76938.0     79296.0
# 8                                   CT    101694.0    107540.0    112064.0
# 9                                   DC     27792.0     25770.0     22437.0
# 10                                  DE     20496.0     20776.0     22586.0
# ...

# %%
# Out:
#     Coal total consumption, billion Btu  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 265                                 NaN    428129.0    455762.0    476680.0
# 266                                 NaN     64968.0     60619.0     61695.0
# 267                                 NaN     23464.0     23666.0     23755.0
# 268                                 NaN      8174.0      8273.0     11746.0
# 269                                 NaN   2928205.0   2952227.0   3117444.0
#
#      Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 265    514264.0    557343.0    581530.0    617245.0    678045.0    736245.0
# 266     55114.0     54980.0     61690.0     60892.0     61003.0     65830.0
# 267     21029.0     21666.0     20560.0     20101.0     22471.0     21573.0
# 268     10641.0     10613.0     10793.0     11106.0      9641.0     11560.0
# 269   3096431.0   3225249.0   3395816.0   3432463.0   3690213.0   3772655.0
#
# ...
