# %%
import pandas as pd

# %%
cancer_df = pd.read_csv('Resources-Artien/2021 State Cancer Data.csv')

# %%
cancer_df.head(52)
# Out:
#                    State  2010 Lung & Bronchus     2010  2011 Lung & Bronchus  \
# 0                Alabama                  4160    23640                  4240
# 1                 Alaska                   360     2860                   380
# 2                Arizona                  4030    29780                  3820
# 3               Arkansas                  2620    15320                  2660
# 4             California                 18490   157320                 17660
# 5               Colorado                  2270    21340                  2250
# 6            Connecticut                  2640    20750                  2680
# 7               Delaware                   800     4890                   780
# 8   District of Columbia                   360     2760                   360
# 9                Florida                 18390   107000                 17150
# 10               Georgia                  6280    40480                  6410
# ...

# %%
cancer_df = cancer_df.drop(columns=['2010 Lung & Bronchus','2010'])

# %%
cancer_df.head()
# Out:
#         State  2011 Lung & Bronchus    2011  2012 Lung & Bronchus    2012  \
# 0     Alabama                  4240   25530                  4440   26440
# 1      Alaska                   380    3090                   490    3640
# 2     Arizona                  3820   31550                  3970   31990
# 3    Arkansas                  2660   16070                  2760   16120
# 4  California                 17660  163480                 18060  165810
#
#    2013 Lung & Bronchus    2013  2014 Lung & Bronchus    2014  \
# 0                  4550   27080                  4160   26770
# 1                   470    3290                   430    3750
# 2                  4250   34010                  4280   32830
# 3                  2700   16330                  2660   16520
# 4                 18720  171330                 18780  171730
#
#    2015 Lung & Bronchus  ...  2016 Lung & Bronchus    2016  \
# 0                  4150  ...                  4220   27020
# ...

# %%
for index, row in cancer_df.iterrows():
    all_avg = (cancer_df['2011']+cancer_df['2012']+cancer_df['2013']+cancer_df['2014']+cancer_df['2015']+cancer_df['2016']+cancer_df['2017']+cancer_df['2018']+cancer_df['2019']+cancer_df['2020'])/10
    lung_bronchus_avg = (cancer_df['2011 Lung & Bronchus']+cancer_df['2012 Lung & Bronchus']+cancer_df['2013 Lung & Bronchus']+cancer_df['2014 Lung & Bronchus']+cancer_df['2015 Lung & Bronchus']+cancer_df['2016 Lung & Bronchus']+cancer_df['2017 Lung & Bronchus']+cancer_df['2018 Lung & Bronchus']+cancer_df['2019 Lung & Bronchus']+cancer_df['2020 Lung & Bronchus'])/10
print(all_avg)  
print(lung_bronchus_avg)
# Out:
# 0       27050.0
# 1        3400.0
# 2       34010.0
# 3       16328.0
# 4      173087.0
# 5       24569.0
# 6       21528.0
# 7        5637.0
# 8        3040.0
# 9      124102.0
# 10      49753.0
# 11       6693.0
# 12       7979.0
# 13      66644.0
# 14      35793.0
# 15      17499.0
# 16      14744.0
# 17      25836.0
# 18      24724.0
# 19       8880.0
# 20      31577.0
# 21      37881.0
# 22      57924.0
# 23      29731.0
# 24      16435.0
# 25      34591.0
# 26       5855.0
# 27       9653.0
# 28      14214.0
# 29       8367.0
# 30      51314.0
# 31       9832.0
# 32     109889.0
# 33      54169.0
# 34       3837.0
# 35      67191.0
# 36      19592.0
# 37      22167.0
# 38      79975.0
# 39       6154.0
# 40      28029.0
# 41       4688.0
# 42      37001.0
# 43     116647.0
# 44      11028.0
# 45       3991.0
# 46      42448.0
# 47      36680.0
# 48      11796.0
# 49      32802.0
# 50       2807.0
# 51    1689816.0
# dtype: float64
# 0       4221.0
# 1        434.0
# ...

# %%
cancer_df['10 year State Total AVGs'] = all_avg
cancer_df['10 year State Lung/Bronchus AVGs'] = lung_bronchus_avg
cancer_df.head()
# Out:
#         State  2011 Lung & Bronchus    2011  2012 Lung & Bronchus    2012  \
# 0     Alabama                  4240   25530                  4440   26440
# 1      Alaska                   380    3090                   490    3640
# 2     Arizona                  3820   31550                  3970   31990
# 3    Arkansas                  2660   16070                  2760   16120
# 4  California                 17660  163480                 18060  165810
#
#    2013 Lung & Bronchus    2013  2014 Lung & Bronchus    2014  \
# 0                  4550   27080                  4160   26770
# 1                   470    3290                   430    3750
# 2                  4250   34010                  4280   32830
# 3                  2700   16330                  2660   16520
# 4                 18720  171330                 18780  171730
#
#    2015 Lung & Bronchus  ...  2018 Lung & Bronchus    2018  \
# 0                  4150  ...                  4190   27830
# ...

# %%
cancer_df['2021'] = [30830,3190,39640,17980,187140,28630,22910,7090,3450,148010,58060,7570,10240,74980,39010,20000,16980,30270,27880,10090,34590,42750,62150,33260,18750,37390,6930,11180,16970,9560,56360,10970,120200,63930,4200,73320,22820,24790,85440,6910,33030,5330,41980,133730,12750,4310,46340,42170,12500,36520,3050,1898160]

# %%
cancer_df['2021 Lung & Bronchus'] = [4520,370,4550,2970,17760,2570,2750,910,360,18470,7250,930,1060,9600,5960,2610,2160,4970,3910,1530,4230,5550,8590,3970,2870,5570,810,1350,2080,1240,5900,960,13950,8830,490,10350,3300,2990,11170,950,4510,650,6410,15010,770,570,5820,4780,2020,4540,320,235760]

# %%
cancer_df.head(60)
# Out:
#                    State  2011 Lung & Bronchus     2011  2012 Lung & Bronchus  \
# 0                Alabama                  4240    25530                  4440
# 1                 Alaska                   380     3090                   490
# 2                Arizona                  3820    31550                  3970
# 3               Arkansas                  2660    16070                  2760
# 4             California                 17660   163480                 18060
# 5               Colorado                  2250    22390                  2400
# 6            Connecticut                  2680    21440                  2720
# 7               Delaware                   780     5130                   800
# 8   District of Columbia                   360     2830                   370
# 9                Florida                 17150   113400                 17860
# 10               Georgia                  6410    44580                  6570
# ...
