# %%
#Import Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd
from pathlib import Path

# %%
# The path to our CSV file
county_data = Path("countycancer.csv")

# Read our cancer data into pandas
county_df = pd.read_csv(county_data)
county_df
# Out:
#                                                  County     FIPS  \
# 0                                     US (SEER+NPCR)(1)      0.0
# 1                              Union County, Florida(6)  12125.0
# 2                             Palo Alto County, Iowa(7)  19147.0
# 3                           Treasure County, Montana(6)  30103.0
# 4                                 Polk County, Texas(7)  48373.0
# ...                                                 ...      ...
# 3171           7 Source: SEER November 2022 submission.      NaN
# 3172  8 Source: Incidence data provided by the SEER ...      NaN
# 3173  Data not available [http://statecancerprofiles...      NaN
# 3174  Data for the United States does not include da...      NaN
# 3175  Data for the United States does not include Pu...      NaN
#
#      Age-Adjusted Incidence Rate([rate note]) - cases per 100,000  \
# 0                                                 442.3
# 1                                                1237.4
# ...

# %%
county_data[['County','']] = df['V'].str.split(',',expand=True)

# %%
#Population Data
# The path to our CSV file
county_pop = Path("Ruralurbancontinuumcodes2023.csv")

# Read our cancer data into pandas
county_pop_df = pd.read_csv(county_pop)
county_pop_df.tail
# Out:
#        FIPS State        County_Name Population_2020  RUCC_2023  \
# 0      1001    AL     Autauga County          58,805        2.0
# 1      1003    AL     Baldwin County         231,767        3.0
# 2      1005    AL     Barbour County          25,223        6.0
# 3      1007    AL        Bibb County          22,293        1.0
# 4      1009    AL      Blount County          59,134        1.0
# ...     ...   ...                ...             ...        ...
# 3230  72151    PR  Yabucoa Municipio          30,426        1.0
# 3231  72153    PR    Yauco Municipio          34,172        2.0
# 3232  78010    VI   St. Croix Island          41,004        5.0
# 3233  78020    VI    St. John Island           3,881        9.0
# 3234  78030    VI  St. Thomas Island          42,261        5.0
#
#                                             Description
# 0     Metro - Counties in metro areas of 250,000 to ...
# 1     Metro - Counties in metro areas of fewer than ...
# ...

# %%
county_pop_df['Population_2020'] = county_pop_df['Population_2020'].str.replace(',', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 county_pop_df['Population_2020'] = county_pop_df['Population_2020'].str.replace(',', '').astype(int)
#       3 # Group by 'State' column
#       4 grouped = county_pop_df.groupby('State')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...

# %%
#groupby and summattion

state_populations = county_pop_df.groupby('State')['Population_2020'].sum()

print(state_populations)
# Out:
# State
# AK      733391
# AL     5024279
# AR     3011524
# AS       49710
# AZ     7151502
# CA    39538223
# CO     5773714
# CT     3605944
# DC      689545
# DE      989948
# FL    21538187
# GA    10711908
# GU      153836
# HI     1455271
# IA     3190369
# ID     1839106
# IL    12812508
# IN     6785528
# KS     2937880
# KY     4505836
# LA     4657757
# MA     7029917
# MD     6177224
# ME     1362359
# MI    10077331
# MN     5706494
# MO     6154913
# MP       47329
# MS     2961279
# MT     1084225
# NC    10439388
# ND      779094
# NE     1961504
# NH     1377529
# NJ     9288994
# NM     2117522
# NV     3104614
# NY    20201249
# OH    11799448
# OK     3959353
# OR     4237256
# PA    13002700
# PR     3285874
# RI     1097379
# SC     5118425
# SD      886667
# TN     6910840
# TX    29145505
# UT     3271616
# VA     8631393
# VI       87146
# VT      643077
# WA     7705281
# WI     5893718
# WV     1793716
# WY      576851
# Name: Population_2020, dtype: int32

# %%
state_populations_df = state_populations.reset_index(name='Total_Population')

state_populations_df
# Out:
#    State  Total_Population
# 0     AK            733391
# 1     AL           5024279
# 2     AR           3011524
# 3     AS             49710
# 4     AZ           7151502
# 5     CA          39538223
# 6     CO           5773714
# 7     CT           3605944
# 8     DC            689545
# 9     DE            989948
# 10    FL          21538187
# 11    GA          10711908
# 12    GU            153836
# 13    HI           1455271
# 14    IA           3190369
# 15    ID           1839106
# 16    IL          12812508
# 17    IN           6785528
# 18    KS           2937880
# 19    KY           4505836
# 20    LA           4657757
# 21    MA           7029917
# 22    MD           6177224
# 23    ME           1362359
# 24    MI          10077331
# 25    MN           5706494
# 26    MO           6154913
# 27    MP             47329
# 28    MS           2961279
# 29    MT           1084225
# 30    NC          10439388
# 31    ND            779094
# 32    NE           1961504
# ...

# %%
state_populations_df.to_csv('state_populations.csv', index=False)
