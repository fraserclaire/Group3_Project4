# %%
#Import Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd
from pathlib import Path
import numpy as np

# %%
state_data = Path("StateCancerDatawPop.csv")

# Read our cancer data into pandas
state_df = pd.read_csv(state_data)
state_df
# Out:
#                    State  2010 Lung & Bronchus     2010   2010 Pop  \
# 0                Alabama                  4160    23640    4779736
# 1                 Alaska                   360     2860     710231
# 2                Arizona                  4030    29780    6392017
# 3               Arkansas                  2620    15320    2915918
# 4             California                 18490   157320   37253956
# 5               Colorado                  2270    21340    5029196
# 6            Connecticut                  2640    20750    3574097
# 7               Delaware                   800     4890     897934
# 8   District of Columbia                   360     2760     601723
# 9                Florida                 18390   107000   18801310
# 10               Georgia                  6280    40480    9687653
# 11                Hawaii                   770     6670    1360301
# 12                 Idaho                   860     7220    1567582
# ...

# %%
target = [1] * len(X)  # Example target values, replace this with your actual target variable

# Initialize logistic regression model
logreg = LogisticRegression()

# Train the model
logreg.fit(df, target)

# Retrieve coefficients
coefficients = logreg.coef_

print("Coefficients (slopes):", coefficients)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 target = [1] * len(X)  # Example target values, replace this with your actual target variable
#       3 # Initialize logistic regression model
#       4 logreg = LogisticRegression()
#
# NameError: name 'X' is not defined
